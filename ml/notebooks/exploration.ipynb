# %% [markdown]
# # MolForge Dataset Exploration
#
# This notebook loads curated sample molecules and prepares descriptor exploration for local model calibration.

# %%
import json
from pathlib import Path

samples = json.loads(Path('../../backend/data/sample_molecules.json').read_text())
len(samples), samples[0]
